# %%
import pandas as pd
import re

# %%
stats = pd.read_csv('C:/Users/ericm/Documents/SoftwareTech/AssignmentPartB/data/Crash Statistics Victoria.csv', index_col=0)

# %%
code = stats['DCA_CODE'].unique()

# %%
display(stats[stats["ACCIDENT_DATE"] == "1/7/2013"])
# Out:
#            ACCIDENT_NO                 ABS_CODE ACCIDENT_STATUS ACCIDENT_DATE  \
# OBJECTID
# 3401744   T20130013732  ABS to receive accident        Finished      1/7/2013
# 3401770   T20130013608  ABS to receive accident        Finished      1/7/2013
# 3401771   T20130013611  ABS to receive accident        Finished      1/7/2013
# 3401772   T20130013617  ABS to receive accident        Finished      1/7/2013
# 3401773   T20130013620  ABS to receive accident        Finished      1/7/2013
# 3401774   T20130013621  ABS to receive accident        Finished      1/7/2013
# 3401775   T20130013622  ABS to receive accident        Finished      1/7/2013
# 3401776   T20130013630  ABS to receive accident        Finished      1/7/2013
# 3401777   T20130013638  ABS to receive accident        Finished      1/7/2013
# 3401778   T20130013641  ABS to receive accident        Finished      1/7/2013
# 3401779   T20130013644  ABS to receive accident        Finished      1/7/2013
# 3401780   T20130013647  ABS to receive accident        Finished      1/7/2013
# 3401781   T20130013649  ABS to receive accident        Finished      1/7/2013
# 3401782   T20130013650  ABS to receive accident        Finished      1/7/2013
# 3401783   T20130013652  ABS to receive accident        Finished      1/7/2013
# 3401784   T20130013654  ABS to receive accident        Finished      1/7/2013
# 3401785   T20130013655  ABS to receive accident        Finished      1/7/2013
# 3401786   T20130013656  ABS to receive accident        Finished      1/7/2013
# 3401787   T20130013657  ABS to receive accident        Finished      1/7/2013
# 3401788   T20130013658  ABS to receive accident        Finished      1/7/2013
# 3401789   T20130013659  ABS to receive accident        Finished      1/7/2013
# 3401790   T20130013662  ABS to receive accident        Finished      1/7/2013
# 3401791   T20130013668  ABS to receive accident        Finished      1/7/2013
# 3401792   T20130013669  ABS to receive accident        Finished      1/7/2013
# 3401793   T20130013671  ABS to receive accident        Finished      1/7/2013
# 3401794   T20130013672  ABS to receive accident        Finished      1/7/2013
# 3401795   T20130013675  ABS to receive accident        Finished      1/7/2013
# 3401796   T20130013678  ABS to receive accident        Finished      1/7/2013
# 3401797   T20130013681  ABS to receive accident        Finished      1/7/2013
# 3401803   T20130013709  ABS to receive accident        Finished      1/7/2013
# 3401804   T20130013712  ABS to receive accident        Finished      1/7/2013
# 3401808   T20130013730  ABS to receive accident        Finished      1/7/2013
# 3401897   T20130013807  ABS to receive accident        Finished      1/7/2013
# 3401908   T20130013830  ABS to receive accident        Finished      1/7/2013
# 3401913   T20130014222  ABS to receive accident        Finished      1/7/2013
# 3401942   T20130014077  ABS to receive accident        Finished      1/7/2013
# 3402168   T20130014576  ABS to receive accident        Finished      1/7/2013
# 3404163   T20130018675  ABS to receive accident        Finished      1/7/2013
# 3404609   T20130018087  ABS to receive accident        Finished      1/7/2013
# 3404691   T20130017262  ABS to receive accident        Finished      1/7/2013
# 3410123   T20140005805  ABS to receive accident        Finished      1/7/2013
#
#          ACCIDENT_TIME ALCOHOLTIME                      ACCIDENT_TYPE  \
# OBJECTID
# 3401744       18.30.00         Yes                  Struck Pedestrian
# 3401770       02.10.00         Yes             Collision with vehicle
# 3401771       06.40.00          No                  Struck Pedestrian
# 3401772       08.40.00          No             Collision with vehicle
# 3401773       05.30.00         Yes      Collision with a fixed object
# 3401774       04.45.00         Yes                      Struck animal
# 3401775       09.14.00          No             Collision with vehicle
# 3401776       06.50.00         Yes  Vehicle overturned (no collision)
# 3401777       10.30.00          No      Collision with a fixed object
# 3401778       09.30.00          No      Collision with a fixed object
# 3401779       12.40.00          No                  Struck Pedestrian
# 3401780       16.40.00          No  Vehicle overturned (no collision)
# 3401781       15.40.00          No             Collision with vehicle
# 3401782       16.40.00          No             Collision with vehicle
# 3401783       17.55.00          No             Collision with vehicle
# 3401784       17.45.00          No             Collision with vehicle
# 3401785       16.45.00          No             Collision with vehicle
# 3401786       16.20.00          No             Collision with vehicle
# 3401787       17.05.00          No      Collision with a fixed object
# 3401788       19.30.00         Yes      Collision with a fixed object
# 3401789       15.57.00          No             Collision with vehicle
# 3401790       18.05.00         Yes             Collision with vehicle
# 3401791       16.16.00          No             Collision with vehicle
# 3401792       19.12.00         Yes             Collision with vehicle
# 3401793       17.52.00          No             Collision with vehicle
# 3401794       18.00.00         Yes                  Struck Pedestrian
# 3401795       21.50.00         Yes                  Struck Pedestrian
# 3401796       07.25.00          No      Collision with a fixed object
# 3401797       14.00.00          No             Collision with vehicle
# 3401803       21.05.00         Yes             Collision with vehicle
# 3401804       15.45.00          No             Collision with vehicle
# 3401808       18.30.00         Yes  Vehicle overturned (no collision)
# 3401897       22.00.00         Yes             Collision with vehicle
# 3401908       19.40.00         Yes   collision with some other object
# 3401913       08.40.00          No             Collision with vehicle
# 3401942       17.00.00          No  No collision and no object struck
# 3402168       13.00.00          No  No collision and no object struck
# 3404163       17.00.00          No             Collision with vehicle
# 3404609       15.15.00          No             Collision with vehicle
# 3404691       19.00.00         Yes             Collision with vehicle
# 3410123       18.00.00         Yes             Collision with vehicle
#
#          DAY_OF_WEEK                                           DCA_CODE  \
# OBJECTID
# 3401744       Monday  PED NEAR SIDE. PED HIT BY VEHICLE FROM THE RIGHT.
# 3401770       Monday                     RIGHT FAR (INTERSECTIONS ONLY)
# 3401771       Monday  PED PLAYING/LYING/WORKING/STANDING ON CARRIAGE...
# 3401772       Monday                                      RIGHT THROUGH
# 3401773       Monday           OFF LEFT BEND INTO OBJECT/PARKED VEHICLE
# 3401774       Monday                                      STRUCK ANIMAL
# 3401775       Monday                    RIGHT NEAR (INTERSECTIONS ONLY)
# 3401776       Sunday                           OFF CARRIAGEWAY TO RIGHT
# 3401777       Monday           OFF LEFT BEND INTO OBJECT/PARKED VEHICLE
# 3401778       Monday    LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE
# 3401779       Monday  VEH STRIKES PED ON FOOTPATH/MEDIAN/TRAFFIC ISL...
# 3401780       Monday        OUT OF CONTROL ON CARRIAGEWAY (ON STRAIGHT)
# 3401781       Monday                    REAR END(VEHICLES IN SAME LANE)
# 3401782       Monday                    RIGHT NEAR (INTERSECTIONS ONLY)
# 3401783       Monday                  CROSS TRAFFIC(INTERSECTIONS ONLY)
# 3401784       Monday                    RIGHT NEAR (INTERSECTIONS ONLY)
# 3401785       Monday                  CROSS TRAFFIC(INTERSECTIONS ONLY)
# 3401786       Monday                    REAR END(VEHICLES IN SAME LANE)
# 3401787       Monday          OFF RIGHT BEND INTO OBJECT/PARKED VEHICLE
# 3401788       Monday    LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE
# 3401789       Monday                  CROSS TRAFFIC(INTERSECTIONS ONLY)
# 3401790       Monday                                      RIGHT THROUGH
# 3401791       Monday                  LANE CHANGE LEFT (NOT OVERTAKING)
# 3401792       Monday  VEHICLE COLLIDES WITH VEHICLE PARKED ON LEFT O...
# 3401793       Monday                              PULLING OUT -REAR END
# 3401794       Monday         FAR SIDE. PED HIT BY VEHICLE FROM THE LEFT
# 3401795       Monday  PED PLAYING/LYING/WORKING/STANDING ON CARRIAGE...
# 3401796       Monday   RIGHT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE
# 3401797       Monday                    RIGHT NEAR (INTERSECTIONS ONLY)
# 3401803       Monday  VEHICLE COLLIDES WITH VEHICLE PARKED ON LEFT O...
# 3401804       Monday                  CROSS TRAFFIC(INTERSECTIONS ONLY)
# 3401808       Monday        OUT OF CONTROL ON CARRIAGEWAY (ON STRAIGHT)
# 3401897       Monday                                      OTHER ON PATH
# 3401908       Monday                     LOAD OR MISSILE STRUCK VEHICLE
# 3401913       Monday                               RIGHT TURN SIDESWIPE
# 3401942       Monday        OUT OF CONTROL ON CARRIAGEWAY (ON STRAIGHT)
# 3402168       Monday        OUT OF CONTROL ON CARRIAGEWAY (ON STRAIGHT)
# 3404163       Monday                     LEFT NEAR (INTERSECTIONS ONLY)
# 3404609       Monday                                      RIGHT THROUGH
# 3404691       Monday                    REAR END(VEHICLES IN SAME LANE)
# 3410123       Monday                                      RIGHT THROUGH
#
#          HIT_RUN_FLAG  ...              DEG_URBAN_ALL  \
# OBJECTID               ...
# 3401744            No  ...                 MELB_URBAN
# 3401770            No  ...                 MELB_URBAN
# 3401771            No  ...    LARGE_PROVINCIAL_CITIES
# 3401772            No  ...                 MELB_URBAN
# 3401773            No  ...             RURAL_VICTORIA
# 3401774            No  ...             RURAL_VICTORIA
# 3401775            No  ...                 MELB_URBAN
# 3401776            No  ...             RURAL_VICTORIA
# 3401777            No  ...             RURAL_VICTORIA
# 3401778            No  ...    LARGE_PROVINCIAL_CITIES
# 3401779            No  ...                 MELB_URBAN
# 3401780            No  ...                 MELB_URBAN
# 3401781            No  ...                 MELB_URBAN
# 3401782            No  ...                 MELB_URBAN
# 3401783            No  ...    LARGE_PROVINCIAL_CITIES
# 3401784            No  ...               SMALL_CITIES
# 3401785            No  ...             RURAL_VICTORIA
# 3401786            No  ...                 MELB_URBAN
# 3401787            No  ...             RURAL_VICTORIA
# 3401788            No  ...                 MELB_URBAN
# 3401789            No  ...             RURAL_VICTORIA
# 3401790            No  ...                 MELB_URBAN
# 3401791            No  ...                 MELB_URBAN
# 3401792            No  ...                 MELB_URBAN
# 3401793            No  ...                 MELB_URBAN
# 3401794            No  ...                 MELB_URBAN
# 3401795           Yes  ...               SMALL_CITIES
# 3401796            No  ...             RURAL_VICTORIA
# 3401797            No  ...                 MELB_URBAN
# 3401803            No  ...                 MELB_URBAN
# 3401804            No  ...                      TOWNS
# 3401808            No  ...                 MELB_URBAN
# 3401897            No  ...                 MELB_URBAN
# 3401908            No  ...                 MELB_URBAN
# 3401913            No  ...                 MELB_URBAN
# 3401942            No  ...                 MELB_URBAN
# 3402168            No  ...  RURAL_VICTORIA,MELB_URBAN
# 3404163            No  ...                 MELB_URBAN
# 3404609            No  ...                 MELB_URBAN
# 3404691            No  ...                 MELB_URBAN
# 3410123            No  ...                 MELB_URBAN
#
#                      LGA_NAME_ALL                 REGION_NAME_ALL SRNS  \
# OBJECTID
# 3401744                 MELBOURNE  METROPOLITAN NORTH WEST REGION  NaN
# 3401770                      KNOX  METROPOLITAN SOUTH EAST REGION  NaN
# 3401771                   GEELONG            SOUTH WESTERN REGION  NaN
# 3401772                     CASEY  METROPOLITAN SOUTH EAST REGION  NaN
# 3401773                   BAW BAW   EASTERN REGION,EASTERN REGION    C
# 3401774                   BENDIGO                 NORTHERN REGION  NaN
# 3401775                 FRANKSTON  METROPOLITAN SOUTH EAST REGION  NaN
# 3401776                  MITCHELL                 NORTHERN REGION    M
# 3401777            EAST GIPPSLAND   EASTERN REGION,EASTERN REGION    B
# 3401778                   GEELONG            SOUTH WESTERN REGION  NaN
# 3401779                   BAYSIDE  METROPOLITAN SOUTH EAST REGION  NaN
# 3401780                BOROONDARA  METROPOLITAN SOUTH EAST REGION  NaN
# 3401781                  KINGSTON  METROPOLITAN SOUTH EAST REGION  NaN
# 3401782                 MAROONDAH  METROPOLITAN SOUTH EAST REGION  NaN
# 3401783                  BALLARAT                  WESTERN REGION  NaN
# 3401784                  CAMPASPE                 NORTHERN REGION    C
# 3401785                SHEPPARTON            NORTH EASTERN REGION    A
# 3401786               HOBSONS BAY  METROPOLITAN NORTH WEST REGION  NaN
# 3401787                 NILLUMBIK  METROPOLITAN NORTH WEST REGION  NaN
# 3401788                      KNOX  METROPOLITAN SOUTH EAST REGION  NaN
# 3401789                   MILDURA                  WESTERN REGION  NaN
# 3401790                      HUME  METROPOLITAN NORTH WEST REGION  NaN
# 3401791                 DANDENONG  METROPOLITAN SOUTH EAST REGION  NaN
# 3401792                    MONASH  METROPOLITAN SOUTH EAST REGION  NaN
# 3401793                      HUME  METROPOLITAN NORTH WEST REGION  NaN
# 3401794                 FRANKSTON  METROPOLITAN SOUTH EAST REGION  NaN
# 3401795                   LATROBE   EASTERN REGION,EASTERN REGION  NaN
# 3401796             GOLDEN PLAINS            SOUTH WESTERN REGION    A
# 3401797                      KNOX  METROPOLITAN SOUTH EAST REGION  NaN
# 3401803                 DANDENONG  METROPOLITAN SOUTH EAST REGION  NaN
# 3401804                   BAW BAW   EASTERN REGION,EASTERN REGION    C
# 3401808             MOONEE VALLEY  METROPOLITAN NORTH WEST REGION    M
# 3401897               MARIBYRNONG  METROPOLITAN NORTH WEST REGION  NaN
# 3401908                      KNOX  METROPOLITAN SOUTH EAST REGION  NaN
# 3401913                 MAROONDAH  METROPOLITAN SOUTH EAST REGION  NaN
# 3401942                BOROONDARA  METROPOLITAN SOUTH EAST REGION  NaN
# 3402168      MORNINGTON PENINSULA  METROPOLITAN SOUTH EAST REGION  NaN
# 3404163               MARIBYRNONG  METROPOLITAN NORTH WEST REGION  NaN
# 3404609                  MORELAND  METROPOLITAN NORTH WEST REGION  NaN
# 3404691                      KNOX  METROPOLITAN SOUTH EAST REGION  NaN
# 3410123   MOONEE VALLEY,MELBOURNE  METROPOLITAN NORTH WEST REGION  NaN
#
#          SRNS_ALL               RMA  \
# OBJECTID
# 3401744       NaN        Local Road
# 3401770       NaN  Arterial Highway
# 3401771       NaN        Local Road
# 3401772       NaN  Arterial Highway
# 3401773         C    Arterial Other
# 3401774       NaN        Local Road
# 3401775       NaN        Local Road
# 3401776         M           Freeway
# 3401777         B  Arterial Highway
# 3401778       NaN        Local Road
# 3401779       NaN        Local Road
# 3401780       NaN    Arterial Other
# 3401781       NaN        Local Road
# 3401782       NaN    Arterial Other
# 3401783       NaN        Local Road
# 3401784         C    Arterial Other
# 3401785       A,C  Arterial Highway
# 3401786       NaN    Arterial Other
# 3401787       NaN        Local Road
# 3401788       NaN        Local Road
# 3401789       NaN        Local Road
# 3401790       NaN    Arterial Other
# 3401791       NaN  Arterial Highway
# 3401792       NaN        Local Road
# 3401793       NaN        Local Road
# 3401794       NaN        Local Road
# 3401795       NaN        Local Road
# 3401796         A  Arterial Highway
# 3401797       NaN    Arterial Other
# 3401803       NaN  Arterial Highway
# 3401804         C    Arterial Other
# 3401808         M           Freeway
# 3401897       NaN  Arterial Highway
# 3401908       NaN    Arterial Other
# 3401913       NaN    Arterial Other
# 3401942       NaN    Arterial Other
# 3402168       NaN        Local Road
# 3404163       NaN    Arterial Other
# 3404609       NaN  Arterial Highway
# 3404691       NaN    Arterial Other
# 3410123       NaN    Arterial Other
#
#                                              RMA_ALL    DIVIDED  DIVIDED_ALL  \
# OBJECTID
# 3401744                                   Local Road  Undivided        Undiv
# 3401770                             Arterial Highway    Divided          Div
# 3401771                                   Local Road  Undivided        Undiv
# 3401772                             Arterial Highway    Divided          Div
# 3401773                               Arterial Other  Undivided        Undiv
# 3401774                                   Local Road  Undivided        Undiv
# 3401775                                   Local Road  Undivided        Undiv
# 3401776                                      Freeway    Divided          Div
# 3401777                             Arterial Highway  Undivided        Undiv
# 3401778                                   Local Road    Divided    Div,Undiv
# 3401779                                   Local Road    Divided    Div,Undiv
# 3401780                    Arterial Other,Local Road  Undivided        Undiv
# 3401781                                   Local Road    Divided    Div,Undiv
# 3401782                    Arterial Other,Local Road    Divided    Div,Undiv
# 3401783                                   Local Road  Undivided        Undiv
# 3401784                    Arterial Other,Local Road  Undivided        Undiv
# 3401785   Arterial Highway,Local Road,Arterial Other  Undivided        Undiv
# 3401786                               Arterial Other  Undivided        Undiv
# 3401787                                   Local Road  Undivided        Undiv
# 3401788                                   Local Road  Undivided        Undiv
# 3401789                                   Local Road  Undivided        Undiv
# 3401790                               Arterial Other    Divided    Div,Undiv
# 3401791                  Arterial Highway,Local Road    Divided    Div,Undiv
# 3401792                                   Local Road  Undivided        Undiv
# 3401793                                   Local Road  Undivided        Undiv
# 3401794                                   Local Road  Undivided        Undiv
# 3401795                                   Local Road  Undivided        Undiv
# 3401796                             Arterial Highway  Undivided        Undiv
# 3401797                    Arterial Other,Local Road  Undivided        Undiv
# 3401803                             Arterial Highway    Divided          Div
# 3401804                    Arterial Other,Local Road  Undivided        Undiv
# 3401808                                      Freeway    Divided          Div
# 3401897                             Arterial Highway    Divided          Div
# 3401908                    Arterial Other,Local Road  Undivided        Undiv
# 3401913                               Arterial Other    Divided          Div
# 3401942                    Arterial Other,Local Road  Undivided        Undiv
# 3402168                                   Local Road  Undivided        Undiv
# 3404163                    Arterial Other,Local Road  Undivided        Undiv
# 3404609                             Arterial Highway  Undivided        Undiv
# 3404691                               Arterial Other    Divided          Div
# 3410123                               Arterial Other  Undivided        Undiv
#
#          STAT_DIV_NAME
# OBJECTID
# 3401744          Metro
# 3401770          Metro
# 3401771        Country
# 3401772          Metro
# 3401773        Country
# 3401774        Country
# 3401775          Metro
# 3401776        Country
# 3401777        Country
# 3401778        Country
# 3401779          Metro
# 3401780          Metro
# 3401781          Metro
# 3401782          Metro
# 3401783        Country
# 3401784        Country
# 3401785        Country
# 3401786          Metro
# 3401787          Metro
# 3401788          Metro
# 3401789        Country
# 3401790          Metro
# 3401791          Metro
# 3401792          Metro
# 3401793          Metro
# 3401794          Metro
# 3401795        Country
# 3401796        Country
# 3401797          Metro
# 3401803          Metro
# 3401804        Country
# 3401808          Metro
# 3401897          Metro
# 3401908          Metro
# 3401913          Metro
# 3401942          Metro
# 3402168          Metro
# 3404163          Metro
# 3404609          Metro
# 3404691          Metro
# 3410123          Metro
#
# [41 rows x 62 columns]
